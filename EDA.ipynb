# %%
import pandas as pd

# %%
import pandas as pd


df = pd.read_csv('cftr-annotated.tsv', sep='\t')


df.head(50)
# Out:
#     PharmGKB ID      Variant         Literature  \
# 0    1183699597  rs113993960   PMCID:PMC3746507
# 1    1446903870  rs113993960      PMID:24973281
# 2    1449154657  rs113993960      PMID:29099344
# 3    1449192546   rs75527207   PMCID:PMC4159205
# 4    1452403346   rs75389940      PMID:38443268
# 5    1449191012   rs11971167      PMID:23891399
# 6    1449192039   rs75527207      PMID:28651844
# 7    1183699587  rs113993960   PMCID:PMC3219147
# 8     982009991   rs75527207   PMCID:PMC3734608
# 9    1449191024    rs1800100      PMID:23891399
# 10   1449192561  rs121909047   PMCID:PMC4209154
# 11   1043737636   rs75527207      PMID:23891399
# 12   1183960706   rs74503330      PMID:22293084
# 13   1449191029  rs397508513      PMID:23891399
# 14   1183960710  rs121909041      PMID:22293084
# 15   1449192055   rs75527207      PMID:28711222
# 16   1449191034  rs115545701      PMID:23891399
# 17   1183960714  rs193922525      PMID:22293084
# ...

# %%
df.to_csv('anno.csv', index=False)

# %%
df2
# Out:
#     PharmGKB ID      Variant         Literature  \
# 0    1183699597  rs113993960   PMCID:PMC3746507
# 1    1446903870  rs113993960      PMID:24973281
# 2    1449154657  rs113993960      PMID:29099344
# 3    1449192546   rs75527207   PMCID:PMC4159205
# 4    1452403346   rs75389940      PMID:38443268
# 5    1449191012   rs11971167      PMID:23891399
# 6    1449192039   rs75527207      PMID:28651844
# 7    1183699587  rs113993960   PMCID:PMC3219147
# 8     982009991   rs75527207   PMCID:PMC3734608
# 9    1449191024    rs1800100      PMID:23891399
# 10   1449192561  rs121909047   PMCID:PMC4209154
# 11   1043737636   rs75527207      PMID:23891399
# 12   1183960706   rs74503330      PMID:22293084
# 13   1449191029  rs397508513      PMID:23891399
# 14   1183960710  rs121909041      PMID:22293084
# 15   1449192055   rs75527207      PMID:28711222
# 16   1449191034  rs115545701      PMID:23891399
# 17   1183960714  rs193922525      PMID:22293084
# ...

# %%
df1=pd.read_csv("/content/anno2.csv")
df2=df1.head(50)
df2
x=df2.iloc[:,-8]
y=df2.iloc[:,-3]
y
# Out:
# 0              IVS8-5T
# 1              IVS8-5T
# 2              IVS8-5T
# 3                R117H
# 4              F508del
# 5               N1303K
# 6                R117H
# 7              IVS8-5T
# 8                R117H
# 9               W1282X
# 10         C.1210-2A>G
# 11               R117H
# 12               G970R
# 13    C.3404_3405delTG
# 14         C.1242+1G>A
# 15               R117H
# 16               G551D
# 17               R334W
# 18             IVS8-5T
# 19               A455E
# 20               R117H
# 21           C.1408C>T
# 22             IVS8-5T
# 23    C.3921_3922delTG
# 24               R347P
# 25              A1067T
# 26             IVS8-5T
# 27          C.212+1G>T
# 28             IVS8-5T
# 29              S1251N
# 30               G551S
# 31               R117H
# 32               R117H
# 33               A455E
# 34               R117H
# 35             F508del
# 36          C.813+1G>A
# 37             IVS8-5T
# 38             IVS8-5T
# 39          C.813+1G>A
# ...

# %%
df3=x,y
df3
val=pd.DataFrame(df3)
val=val.T
val
# Out:
#    Phenotype Categories          Mutation
# 0              Toxicity           IVS8-5T
# 1              Efficacy           IVS8-5T
# 2                 Other           IVS8-5T
# 3              Efficacy             R117H
# 4              Efficacy           F508del
# 5              Efficacy            N1303K
# 6              Efficacy             R117H
# 7              Efficacy           IVS8-5T
# 8              Efficacy             R117H
# 9              Efficacy            W1282X
# 10             Efficacy       C.1210-2A>G
# 11             Efficacy             R117H
# 12             Efficacy             G970R
# 13             Efficacy  C.3404_3405delTG
# 14             Efficacy       C.1242+1G>A
# 15             Efficacy             R117H
# 16             Efficacy             G551D
# 17             Efficacy             R334W
# 18             Toxicity           IVS8-5T
# 19             Efficacy             A455E
# 20             Efficacy             R117H
# ...

# %%
import altair as alt


mutation_counts = val.groupby(['Phenotype Categories', 'Mutation']).size().reset_index(name='counts')



alt.Chart(mutation_counts).mark_bar().encode(
    x=alt.X('Mutation', sort='-y'),
    y='counts',
    color='Phenotype Categories',
    tooltip=['Mutation', 'Phenotype Categories', 'counts']
).properties(
    width=600,
    height=400,
    title="Count of Mutations per Phenotype Category"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/altair/utils/core.py:384: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /usr/local/lib/python3.10/dist-packages/altair/utils/core.py:384: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
